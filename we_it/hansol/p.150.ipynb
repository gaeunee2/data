# %%
import pandas as pd

# %%
import numpy as np

# %%
#Q1

# %%
mpg = pd.read_csv('mpg.csv')

# %%
mpg_new = mpg[['category', 'cty']]

# %%
mpg_new
# Out:
#     category  cty
# 0    compact   18
# 1    compact   21
# 2    compact   20
# 3    compact   21
# 4    compact   16
# ..       ...  ...
# 229  midsize   19
# 230  midsize   21
# 231  midsize   16
# 232  midsize   18
# 233  midsize   17
#
# [234 rows x 2 columns]

# %%
#Q2

# %%
suv = mpg_new.query('category == "suv"')

# %%
suv
# Out:
#     category  cty
# 18       suv   14
# 19       suv   11
# 20       suv   14
# 21       suv   13
# 22       suv   12
# ..       ...  ...
# 176      suv   15
# 177      suv   16
# 178      suv   14
# 198      suv   11
# 199      suv   13
#
# [62 rows x 2 columns]

# %%
suv['cty'].mean()
# Out:
# 13.5

# %%
compact = mpg_new.query('category == "compact"')

# %%
compact
# Out:
#     category  cty
# 0    compact   18
# 1    compact   21
# 2    compact   20
# 3    compact   21
# 4    compact   16
# 5    compact   18
# 6    compact   18
# 7    compact   18
# 8    compact   16
# 9    compact   20
# 10   compact   19
# 11   compact   15
# 12   compact   17
# 13   compact   17
# 14   compact   15
# 141  compact   21
# 142  compact   19
# 169  compact   20
# 170  compact   20
# 171  compact   19
# 172  compact   20
# 186  compact   21
# 187  compact   21
# 188  compact   21
# 189  compact   22
# 190  compact   18
# 191  compact   18
# 192  compact   18
# 193  compact   24
# 194  compact   24
# 195  compact   26
# 196  compact   28
# 197  compact   26
# 207  compact   21
# 208  compact   19
# 209  compact   21
# 210  compact   22
# 211  compact   17
# 212  compact   33
# 213  compact   21
# 214  compact   19
# 215  compact   22
# 216  compact   21
# 217  compact   21
# 218  compact   21
# 219  compact   16
# 220  compact   17

# %%
compact['cty'].mean()
# Out:
# 20.127659574468087
