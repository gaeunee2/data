# %%
#p225 데이터 분석 준비
import pandas as pd
import numpy as np
import seaborn as sns

raw_welfare = pd.read_spss('Koweps_hpwc14_2019_beta2.sav')
welfare = raw_welfare.copy()

#데이터 검토
welfare #앞, 뒷부분 출력
welfare.shape #행, 열 개수 출력
welfare.info() #변수 속성 출력
welfare.describe() #요약 통계량

#변수명 변경
welfare = welfare.rename(
    columns = {'h14_g3': 'sex', #성별
               'h14_g4': 'birth', #태어난 연도
               'h14_g10': 'marriage_type', #혼인 상태
               'h14_g11': 'religion', #종교
               'p1402_8aq1': 'income', #월급
               'h14_eco9': 'code_job', #직업 코드
               'h14_reg7': 'code_region'}) #지역 코드

# %%
#p229 성별에 따른 월급 차이
import pandas as pd
import numpy as np
import seaborn as sns

raw_welfare = pd.read_spss('Koweps_hpwc14_2019_beta2.sav')
welfare = raw_welfare.copy()
welfare = welfare.rename(
    columns = {'h14_g3': 'sex', #성별
               'h14_g4': 'birth', #태어난 연도
               'h14_g10': 'marriage_type', #혼인 상태
               'h14_g11': 'religion', #종교
               'p1402_8aq1': 'income', #월급
               'h14_eco9': 'code_job', #직업 코드
               'h14_reg7': 'code_region'}) #지역 코드

welfare['sex'].dtypes #변수 타입 출력, float64
welfare['sex'].value_counts() #빈도 구하기 #1남 2여 9모름
welfare['sex'] = np.where(welfare['sex'] == 1, 'male', 'female')
welfare['sex'].value_counts()
sns.countplot(data = welfare, x = 'sex');

welfare['income'].dtypes #변수 타입 출력, float64
welfare['income'].describe() #요약통계량
sns.histplot(data = welfare, x = 'income'); #히스토그램
welfare['income'].describe() #이상치 확인
welfare['income'].isna().sum() #결측치 확인

#성별 월급 평균표 만들기
sex_income = welfare.dropna(subset = 'income')\
                    .groupby('sex', as_index = False)\
                    .agg(mean_income = ('income', 'mean'))
sns.barplot(data = sex_income, x = 'sex', y = 'mean_income');

# %%
#p235 나이와 월급의 관계
import pandas as pd
import numpy as np
import seaborn as sns

raw_welfare = pd.read_spss('Koweps_hpwc14_2019_beta2.sav')
welfare = raw_welfare.copy()
welfare = welfare.rename(
    columns = {'h14_g3': 'sex', #성별
               'h14_g4': 'birth', #태어난 연도
               'h14_g10': 'marriage_type', #혼인 상태
               'h14_g11': 'religion', #종교
               'p1402_8aq1': 'income', #월급
               'h14_eco9': 'code_job', #직업 코드
               'h14_reg7': 'code_region'}) #지역 코드

welfare['birth'].dtypes #변수 타입, float64
welfare['birth'].describe() #요약통계량
#sns.histplot(data = welfare, x = 'birth');

welfare['birth'].describe() #이상치 확인
welfare['birth'].isna().sum() #결측치 확인
welfare = welfare.assign(age = 2019 - welfare['birth'] + 1) #나이 변수 만들기
welfare['age'].describe() #요약통계량
#sns.histplot(data = welfare, x = 'age');

#나이별 월급 평균표 만들기
age_income = welfare.dropna(subset = 'income')\
                    .groupby('age')\
                    .agg(mean_income = ('income', 'mean'))
sns.lineplot(data = age_income, x = 'age', y = 'mean_income');

# %%
#p240 연령대에 따른 월급 차이
import pandas as pd
import numpy as np
import seaborn as sns

raw_welfare = pd.read_spss('Koweps_hpwc14_2019_beta2.sav')
welfare = raw_welfare.copy()
welfare = welfare.rename(
    columns = {'h14_g3': 'sex', #성별
               'h14_g4': 'birth', #태어난 연도
               'h14_g10': 'marriage_type', #혼인 상태
               'h14_g11': 'religion', #종교
               'p1402_8aq1': 'income', #월급
               'h14_eco9': 'code_job', #직업 코드
               'h14_reg7': 'code_region'}) #지역 코드
welfare = welfare.assign(age = 2019 - welfare['birth'] + 1) #나이 변수 만들기

welfare['age'].head() #나이변수
welfare = welfare.assign(ageg = np.where(welfare['age'] < 30, 'young',
                                np.where(welfare['age'] <= 59, 'middle',
                                                               'old')))
welfare['ageg'].value_counts() #빈도 구하기
#sns.countplot(data = welfare, x = 'ageg'); #빈도 막대 그래프

#연령대별 월급 평균표 만들기
ageg_income = welfare.dropna(subset = 'income')\
                     .groupby('ageg', as_index = False)\
                     .agg(mean_income = ('income', 'mean'))
sns.barplot(data = ageg_income, x = 'ageg', y = 'mean_income',
            order = ['young', 'middle', 'old']);

# %%
#p244 연령대 및 성별 월급 차이
import pandas as pd
import numpy as np
import seaborn as sns

raw_welfare = pd.read_spss('Koweps_hpwc14_2019_beta2.sav')
welfare = raw_welfare.copy()
welfare = welfare.rename(
    columns = {'h14_g3': 'sex', #성별
               'h14_g4': 'birth', #태어난 연도
               'h14_g10': 'marriage_type', #혼인 상태
               'h14_g11': 'religion', #종교
               'p1402_8aq1': 'income', #월급
               'h14_eco9': 'code_job', #직업 코드
               'h14_reg7': 'code_region'}) #지역 코드
welfare['sex'] = np.where(welfare['sex'] == 1, 'male', 'female')
welfare = welfare.assign(age = 2019 - welfare['birth'] + 1) #나이 변수 만들기
welfare['age'].head() #나이변수
welfare = welfare.assign(ageg = np.where(welfare['age'] < 30, 'young',
                                np.where(welfare['age'] <= 59, 'middle',
                                                               'old')))

#연령대 및 성별 평균표 만들기
sex_income = \
    welfare.dropna(subset = 'income')\
            .groupby(['ageg', 'sex'], as_index = False)\
            .agg(mean_income = ('income', 'mean'))
sns.barplot(data = sex_income, x = 'ageg', y = 'mean_income',
            hue = 'sex', order = ['young', 'middle', 'old']);

#나이 및 성별 월급 평균표 만들기
sex_age = welfare.dropna(subset = 'income')\
                 .groupby(['age', 'sex'], as_index = False)\
                 .agg(mean_income = ('income', 'mean'))
sns.lineplot(data = sex_age, x = 'age', y = 'mean_income', hue = 'sex');

# %%
#p248 직업별 월급 차이
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

raw_welfare = pd.read_spss('Koweps_hpwc14_2019_beta2.sav')
welfare = raw_welfare.copy()
welfare = welfare.rename(
    columns = {'h14_g3': 'sex', #성별
               'h14_g4': 'birth', #태어난 연도
               'h14_g10': 'marriage_type', #혼인 상태
               'h14_g11': 'religion', #종교
               'p1402_8aq1': 'income', #월급
               'h14_eco9': 'code_job', #직업 코드
               'h14_reg7': 'code_region'}) #지역 코드

welfare['code_job'].dtypes #변수 타입, float64
welfare['code_job'].value_counts() #빈도
list_job = pd.read_excel('Koweps_Codebook_2019.xlsx', sheet_name = '직종코드')
list_job.head()
list_job.shape #행, 열 개수 출력 (156, 2)

#welfare에 list_job 결합
welfare = welfare.merge(list_job, how = 'left', on = 'code_job')
welfare.dropna(subset = 'code_job')[['code_job', 'job']].head()


#직업별 월급 평균표 만들기
job_income = welfare.dropna(subset = ['job', 'income'])\
                    .groupby('job', as_index = False)\
                    .agg(mean_income = ('income', 'mean'))
job_income.head()

#그래프
top10 = job_income.sort_values('mean_income', ascending = False).head(10)
plt.rcParams.update({'font.family': 'Malgun Gothic'})
sns.barplot(data = top10, y = 'job', x = 'mean_income');

#하위 10
bottom10 = job_income.sort_values('mean_income').head(10)
bottom10
sns.barplot(data = bottom10, y = 'job', x = 'mean_income')\
    .set(xlim = [0, 800])

# %%
#p255 성별 직업 빈도
import pandas as pd
import numpy as np
import seaborn as sns

raw_welfare = pd.read_spss('Koweps_hpwc14_2019_beta2.sav')
welfare = raw_welfare.copy()
welfare = welfare.rename(
    columns = {'h14_g3': 'sex', #성별
               'h14_g4': 'birth', #태어난 연도
               'h14_g10': 'marriage_type', #혼인 상태
               'h14_g11': 'religion', #종교
               'p1402_8aq1': 'income', #월급
               'h14_eco9': 'code_job', #직업 코드
               'h14_reg7': 'code_region'}) #지역 코드

welfare['sex'].dtypes #변수 타입 출력, float64
welfare['sex'].value_counts() #빈도 구하기 #1남 2여 9모름
welfare['sex'] = np.where(welfare['sex'] == 1, 'male', 'female')
welfare['sex'].value_counts()

welfare['code_job'].dtypes #변수 타입, float64
welfare['code_job'].value_counts() #빈도
list_job = pd.read_excel('Koweps_Codebook_2019.xlsx', sheet_name = '직종코드')
list_job.head()
list_job.shape #행, 열 개수 출력 (156, 2)

#welfare에 list_job 결합
welfare = welfare.merge(list_job, how = 'left', on = 'code_job')
welfare.dropna(subset = 'code_job')[['code_job', 'job']].head()

#남성 직업 빈도 상위 10 추출
job_male = welfare.dropna(subset = 'job')\
                  .query('sex == "male"')\
                  .groupby('job', as_index = False)\
                  .agg(n = ('job', 'count'))\
                  .sort_values('n', ascending = False)\
                  .head(10)
job_male

#여성 직업 빈도 상위 10 추출
job_female = welfare.dropna(subset = 'job')\
                  .query('sex == "female"')\
                  .groupby('job', as_index = False)\
                  .agg(n = ('job', 'count'))\
                  .sort_values('n', ascending = False)\
                  .head(10)
job_female

#남성 직업 빈도 막대 그래프
sns.barplot(data = job_male, y = 'job', x = 'n').set(xlim = [0, 500])

#여성 직업 빈도 막대 그랲프
sns.barplot(data = job_female, y = 'job', x = 'n').set(xlim = [0, 500])

# %%
#p259 종교 유무에 따른 이혼율
import pandas as pd
import numpy as np
import seaborn as sns

raw_welfare = pd.read_spss('Koweps_hpwc14_2019_beta2.sav')
welfare = raw_welfare.copy()
welfare = welfare.rename(
    columns = {'h14_g3': 'sex', #성별
               'h14_g4': 'birth', #태어난 연도
               'h14_g10': 'marriage_type', #혼인 상태
               'h14_g11': 'religion', #종교
               'p1402_8aq1': 'income', #월급
               'h14_eco9': 'code_job', #직업 코드
               'h14_reg7': 'code_region'}) #지역 코드

welfare['religion'].dtypes #변수 타입 출력, float64
welfare['religion'].value_counts() #빈도
#종교 유무 이름 부여
welfare['religion'] = np.where(welfare['religion'] == 1, 'yes', 'no')
welfare['religion'].value_counts()
sns.countplot(data = welfare, x = 'religion');

welfare = welfare.assign(age = 2019 - welfare['birth'] + 1) #나이 변수 만들기
welfare['age'].head() #나이변수
welfare = welfare.assign(ageg = np.where(welfare['age'] < 30, 'young',
                                np.where(welfare['age'] <= 59, 'middle',
                                                               'old')))

welfare['marriage_type'].dtypes #float64
welfare['marriage_type'].value_counts()
#이혼 여부 변수 만들기
welfare['marriage'] = np.where(welfare['marriage_type'] == 1, 'marriage',
                           np.where(welfare['marriage_type'] == 3, 'divorce',
                                                                   'etc'))
n_divorce = welfare.groupby('marriage', as_index = False)\
                   .agg(n = ('marriage', 'count'))
sns.barplot(data = n_divorce, x = 'marriage', y = 'n')

rel_div = welfare.query('marriage != "etc"')\
                 .groupby('religion', as_index = False)\
                ['marriage']\
                 .value_counts(normalize = True)

rel_div = rel_div.query('marriage == "divorce"')\
                 .assign(proportion = rel_div['proportion'] * 100)\
                 .round(1)
sns.barplot(data = rel_div, x = 'religion', y = 'proportion');

#연령대별 이혼율표
age_div = welfare.query('marriage != "etc"')\
                 .groupby('ageg', as_index = False)\
                 ['marriage']\
                 .value_counts(normalize = True)
welfare.query('marriage != "etc"')\
       .groupby('ageg', as_index = False)\
       ['marriage']\
       .value_counts()

age_div = age_div.query('ageg != "young" & marriage == "divorce"')\
                 .assign(proportion = age_div['proportion'] * 100)\
                 .round(1)
sns.barplot(data = age_div, x = 'ageg', y = 'proportion');

age_rel_div = welfare.query('marriage != "etc" & ageg != "young"')\
                     .groupby(['ageg', 'religion'], as_index = False)\
                     ['marriage']\
                     .value_counts(normalize = True)

age_rel_div = \
    age_rel_div.query('marriage == "divorce"')\
               .assign(proportion = age_rel_div['proportion'] * 100)\
               .round(1)
sns.barplot(data = age_rel_div, x = 'ageg', y = 'proportion',
            hue = 'religion');

# %%
#p269 지역별 연령대 비율
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

raw_welfare = pd.read_spss('Koweps_hpwc14_2019_beta2.sav')
welfare = raw_welfare.copy()
welfare = welfare.rename(
    columns = {'h14_g3': 'sex', #성별
               'h14_g4': 'birth', #태어난 연도
               'h14_g10': 'marriage_type', #혼인 상태
               'h14_g11': 'religion', #종교
               'p1402_8aq1': 'income', #월급
               'h14_eco9': 'code_job', #직업 코드
               'h14_reg7': 'code_region'}) #지역 코드

welfare['code_region'].dtypes #float64
welfare['code_region'].value_counts()
#지역 코드 목록 만들기
list_region = pd.DataFrame({'code_region': [1, 2, 3, 4, 5, 6, 7],
                            'region': ['서울',
                                       '수도권(인천/경기)',
                                       '부산/경남/울산',
                                       '대구/경북',
                                       '대전/충남',
                                       '강원/충북',
                                       '광주/전남/전북/제주도']})
#지역명 변수 추가
welfare = welfare.merge(list_region, how = 'left', on = 'code_region')
welfare[['code_region', 'region']].head()

welfare = welfare.assign(age = 2019 - welfare['birth'] + 1) #나이 변수 만들기
welfare['age'].head() #나이변수
welfare = welfare.assign(ageg = np.where(welfare['age'] < 30, 'young',
                                np.where(welfare['age'] <= 59, 'middle',
                                                               'old')))

region_ageg = welfare.groupby('region', as_index = False)\
                     ['ageg']\
                     .value_counts(normalize = True)
region_ageg = \
    region_ageg.assign(proportion = region_ageg['proportion'] * 100) \
               .round(1)
plt.rcParams.update({'font.family': 'Malgun Gothic'})
sns.barplot(data = region_ageg, y = 'region', x = 'proportion', hue = 'ageg');

#피벗
pivot_df = \
    region_ageg[['region', 'ageg', 'proportion']].pivot(index = 'region',
                                                        columns = 'ageg',
                                                        values = 'proportion')
reorder_df = pivot_df.sort_values('old')[['young', 'middle', 'old']]
reorder_df.plot.barh(stacked = True);
